# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Input
from keras.optimizers import SGD, Adam
from keras.losses import Huber

# %%
def plot_predictions(test, predicted):
  plt.plot(test, color='red', label='Real IBM Stock Price')
  plt.plot(predicted, color='blue', label='Predicted IBM Stock Price')
  plt.title('IBM Stock Price Prediction')
  plt.xlabel('Time')
  plt.ylabel('IBM Stock Price')
  plt.legend()
  plt.show()

def return_rmse(test, predicted):
  rmse = math.sqrt(mean_squared_error(test, predicted))
  print("-" * 30)
  print("Błąd średniokwadratowy modelu {:.2f}.".format(rmse))
  print("-" * 30)

def return_mae(test, predicted):
  mae = mean_absolute_error(test, predicted)
  mape = mean_absolute_percentage_error(test, predicted) * 100
  print("Średni błąd bezwzględny {:.2f}.".format(mae))
  print("Średni błąd bezwzględny procentowy {:.2f}%".format(mape))
  print("-" * 30)

# %%
dataset = pd.read_csv('IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
training_set = dataset[:'2016'].iloc[:,3:4].values
test_set = dataset['2017':].iloc[:,3:4].values

# %%
dataset["Close"][:'2016'].plot(figsize=(16,4), legend=True)
dataset["Close"]['2017':].plot(figsize=(16,4), legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM Stock Price')
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2769):
  X_train.append(training_set_scaled[i-60:i, 0])
  y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(Input(shape=(X_train.shape[1], 1)))
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=100, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=100))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))

regressor.compile(optimizer='adam', loss=Huber())
regressor.fit(X_train, y_train, epochs=100, batch_size=32)

#early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#regressor.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0103
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0017
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0018
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0015
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0012
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0013
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.5655e-04
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8546e-04
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 9.4411e-04
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.7225e-04
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.9682e-04
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.5568e-04
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.5034e-04
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.6225e-04
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3062e-04
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5013e-04
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.5217e-04
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 7.3213e-04
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.4865e-04
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.9827e-04
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.6129e-04
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3376e-04
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4320e-04
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4275e-04
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.3875e-04
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 6.5590e-04
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 6.2837e-04
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.3438e-04
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5925e-04
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.6287e-04
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6888e-04
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4177e-04
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9409e-04
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0582e-04
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 5.4380e-04
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1274e-04
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9378e-04
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9747e-04
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7499e-04
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7946e-04
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8190e-04
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6815e-04
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5278e-04
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 5.2910e-04
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.3256e-04
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 4.7223e-04
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8519e-04
# Epoch 57/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5605e-04
# Epoch 58/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5548e-04
# Epoch 59/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3850e-04
# Epoch 60/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.1307e-04
# Epoch 61/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.2234e-04
# Epoch 62/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.1281e-04
# Epoch 63/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9012e-04
# Epoch 64/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1658e-04
# Epoch 65/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2335e-04
# Epoch 66/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0458e-04
# Epoch 67/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9146e-04
# Epoch 68/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.7865e-04
# Epoch 69/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.9111e-04
# Epoch 70/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2494e-04
# Epoch 71/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8621e-04
# Epoch 72/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6933e-04
# Epoch 73/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5199e-04
# Epoch 74/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6140e-04
# Epoch 75/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6018e-04
# Epoch 76/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6397e-04
# Epoch 77/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.6153e-04
# Epoch 78/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.3200e-04
# Epoch 79/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2107e-04
# Epoch 80/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1029e-04
# Epoch 81/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5091e-04
# Epoch 82/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 3.3853e-04
# Epoch 83/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6918e-04
# Epoch 84/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7903e-04
# Epoch 85/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.6388e-04
# Epoch 86/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.4557e-04
# Epoch 87/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.5100e-04
# Epoch 88/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5185e-04
# Epoch 89/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6429e-04
# Epoch 90/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3677e-04
# Epoch 91/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1826e-04
# Epoch 92/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5504e-04
# Epoch 93/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.6641e-04
# Epoch 94/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.5629e-04
# Epoch 95/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4245e-04
# Epoch 96/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6776e-04
# Epoch 97/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2734e-04
# Epoch 98/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0542e-04
# Epoch 99/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5124e-04
# Epoch 100/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2898e-04

# %%
dataset_total = pd.concat((dataset["Close"][:'2016'], dataset["Close"]['2017':]), axis=0)
inputs = dataset_total[len(dataset_total) - len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
X_test = []
for i in range(60, 311):
  X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step

# %%
plot_predictions(test_set, predicted_stock_price)

# %%
return_rmse(test_set, predicted_stock_price)
return_mae(test_set, predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 1.66.
# ------------------------------
# Średni błąd bezwzględny 1.08.
# Średni błąd bezwzględny procentowy 0.68%
# ------------------------------

# %%
regressorGRU = Sequential()
regressorGRU.add(Input(shape=(X_train.shape[1], 1)))
regressorGRU.add(GRU(units=100, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=100, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=100, return_sequences=True, activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(GRU(units=100, activation='tanh'))
regressorGRU.add(Dropout(0.2))
regressorGRU.add(Dense(units=1))

regressorGRU.compile(optimizer='adam', loss=Huber())
regressorGRU.fit(X_train, y_train, epochs=100, batch_size=32)

#early_stop_gru = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#regressorGRU.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[early_stop_gru])
# Out:
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0067
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.6290e-04
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.2389e-04
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 9.3417e-04
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.4069e-04
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.8044e-04
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.7663e-04
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.8330e-04
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6914e-04
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4519e-04
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.5332e-04
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.9934e-04
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.0211e-04
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4521e-04
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.0240e-04
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.8299e-04
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4138e-04
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1801e-04
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8794e-04
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.3494e-04
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 6.6090e-04
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 7.0504e-04
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7801e-04
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.0588e-04
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3931e-04
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3109e-04
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.3409e-04
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7541e-04
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3523e-04
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 5.3819e-04
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.6943e-04
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.0763e-04
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4276e-04
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8041e-04
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0521e-04
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4885e-04
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8235e-04
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9272e-04
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.4477e-04
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2604e-04
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.3241e-04
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2690e-04
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7058e-04
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3914e-04
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2952e-04
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4336e-04
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2843e-04
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.2745e-04
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.7547e-04
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1968e-04
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9067e-04
# Epoch 57/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9590e-04
# Epoch 58/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1366e-04
# Epoch 59/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9053e-04
# Epoch 60/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8782e-04
# Epoch 61/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8973e-04
# Epoch 62/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.8082e-04
# Epoch 63/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.7768e-04
# Epoch 64/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0512e-04
# Epoch 65/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6905e-04
# Epoch 66/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9960e-04
# Epoch 67/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9899e-04
# Epoch 68/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4159e-04
# Epoch 69/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6850e-04
# Epoch 70/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2751e-04
# Epoch 71/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.8633e-04
# Epoch 72/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3418e-04
# Epoch 73/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.3492e-04
# Epoch 74/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7883e-04
# Epoch 75/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3910e-04
# Epoch 76/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4142e-04
# Epoch 77/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4025e-04
# Epoch 78/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5720e-04
# Epoch 79/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5248e-04
# Epoch 80/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.2479e-04
# Epoch 81/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.4233e-04
# Epoch 82/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3514e-04
# Epoch 83/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3367e-04
# Epoch 84/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1539e-04
# Epoch 85/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4372e-04
# Epoch 86/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1023e-04
# Epoch 87/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4983e-04
# Epoch 88/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4289e-04
# Epoch 89/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.3674e-04
# Epoch 90/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2.8864e-04
# Epoch 91/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8364e-04
# Epoch 92/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3054e-04
# Epoch 93/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8108e-04
# Epoch 94/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0280e-04
# Epoch 95/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6825e-04
# Epoch 96/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8420e-04
# Epoch 97/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2611e-04
# Epoch 98/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.8924e-04
# Epoch 99/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0743e-04
# Epoch 100/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8355e-04

# %%
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step

# %%
plot_predictions(test_set, GRU_predicted_stock_price)

# %%
return_rmse(test_set, GRU_predicted_stock_price)
return_mae(test_set, GRU_predicted_stock_price)
# Out:
# ------------------------------
# Błąd średniokwadratowy modelu 1.80.
# ------------------------------
# Średni błąd bezwzględny 1.23.
# Średni błąd bezwzględny procentowy 0.76%
# ------------------------------
